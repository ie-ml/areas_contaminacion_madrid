# %%
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
datos = pd.read_csv('datos201812.csv', sep= ';',error_bad_lines = False)
estaciones = pd.read_csv('estaciones.csv', sep= ';',encoding = "ISO-8859-1", error_bad_lines = False)

# %%
datos.head(20)
# Out:
#     PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES   D01  \
# 0          28         79         4         1  28079004_1_38  2018    1   1.0
# 1          28         79         4         1  28079004_1_38  2018    2   5.0
# 2          28         79         4         1  28079004_1_38  2018    3   1.0
# 3          28         79         4         1  28079004_1_38  2018    4   2.0
# 4          28         79         4         1  28079004_1_38  2018    5   2.0
# 5          28         79         4         1  28079004_1_38  2018    6   3.0
# 6          28         79         4         1  28079004_1_38  2018    7   2.0
# 7          28         79         4         1  28079004_1_38  2018    8   9.0
# 8          28         79         4         1  28079004_1_38  2018    9  10.0
# 9          28         79         4         1  28079004_1_38  2018   10  10.0
# 10         28         79         4         1  28079004_1_38  2018   11  11.0
# ...

# %%
estaciones.head(50)
# Out:
#     NÚMERO                ESTACIÓN  \
# 0        4          Pza. de España
# 1        8        Escuelas Aguirre
# 2       11     Avda. Ramón y Cajal
# 3       16            Arturo Soria
# 4       17              Villaverde
# 5       18               Farolillo
# 6       24           Casa de Campo
# 7       27          Barajas Pueblo
# 8       35         Pza. del Carmen
# 9       36               Moratalaz
# 10      38          Cuatro Caminos
# 11      39        Barrio del Pilar
# 12      40                Vallecas
# 13      47           Mendez Alvaro
# 14      48              Castellana
# 15      49       Parque del Retiro
# 16      50          Plaza Castilla
# 17      54    Ensanche de Vallecas
# 18      55           Urb. Embajada
# 19      56  Pza. Fernández Ladreda
# 20      57             Sanchinarro
# 21      58                El Pardo
# 22      59           Juan Carlos I
# 23      60             Tres Olivos
#
# ...

# %%
datos.describe()
# Out:
#        PROVINCIA  MUNICIPIO     ESTACION     MAGNITUD     ANO          MES  \
# count     1806.0     1806.0  1806.000000  1806.000000  1806.0  1806.000000
# mean        28.0       79.0    34.651163    13.159468  2018.0     6.500000
# std          0.0        0.0    17.959731    10.524897     0.0     3.457338
# min         28.0       79.0     4.000000     1.000000  2018.0     1.000000
# 25%         28.0       79.0    18.000000     7.000000  2018.0     3.000000
# 50%         28.0       79.0    38.000000    10.000000  2018.0     6.500000
# 75%         28.0       79.0    54.000000    14.000000  2018.0    10.000000
# max         28.0       79.0    60.000000    44.000000  2018.0    12.000000
#
#                D01          D02          D03          D04     ...       \
# count  1806.000000  1806.000000  1806.000000  1806.000000     ...
# mean     24.953156    23.037774    25.342359    25.894452     ...
# std      32.467819    26.509996    29.414667    41.258465     ...
# ...

# %%
plt.plot(datos.D31)

# %%
x = datos.D31

# %%
plt.figure(figsize=(10,8))
sns.distplot(x);

# %%
sns.jointplot(data=datos, x='D31', y='D15', kind='kde');

# %%
plt.figure(figsize=(10,8))
sns.pairplot(datos[['D15', 'D31']]);
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-2d98f1b40dd2> in <module>()
# ----> 1 universo
#
# NameError: name 'universo' is not defined
