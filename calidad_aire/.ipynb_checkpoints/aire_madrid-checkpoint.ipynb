# %% [markdown]
# # INICIO DE ANALISIS AIRE MADRID 2018

# %%
# Librerias Generales
import pandas as pd
import seaborn as sns

# %%
# Librerias ploteo

import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
# Carga de CSV

aire2019 = pd.read_csv('datos201901.csv', sep = ';')
aire2018 = pd.read_csv('datos201812.csv', sep = ';')
aire2018_1 = pd.read_csv('datos201812_1.csv', sep = ';')

toxicos =pd.read_csv('toxicos.csv', sep=";",encoding = "ISO-8859-1", header = None)

# %% [markdown]
# ### Tabla de toxicos y definciones

# %%
toxicos.head()
# Out:
#    ID_TOXICO          NOMBRE_TOXICO ABREVIATURA UNIDAD  ID_TECNICA  \
# 0          1      Dióxido de Azufre         SO2  µg/m3          38
# 1          6    Monóxido de Carbono          CO  mg/m3          48
# 2          7  Monóxido de Nitrógeno          NO  µg/m3           8
# 3          8   Dióxido de Nitrógeno         NO2  µg/m3           8
# 4          9    Partículas < 2.5 µm       PM2.5  µg/m3          47
#
#                 TECNICA_MEDIDA
# 0  Fluorescencia Ultravioleta
# 1        Absorción infrarroja
# 2        Quimioluminiscencia
# 3                        Id.
# 4               Microbalanza

# %%
# Rellenamos posibles NaN
toxicos = toxicos.fillna("")

# %%
# toxicos= toxicos.drop(['NOMBRE_TOXICO'], axis = 1)

# %%
# Concatenamos Columnas

toxicos['NOMBRE_TOXICO'] = toxicos[1] +' '+ toxicos[2]+' '+ toxicos[3]
toxicos['TECNICA_MEDIDA'] =  toxicos[7]+' '+ toxicos[8]+' '+ toxicos[9]

# %%
# Renombramos columnas

toxicos.columns = ['ID_TOXICO', 'N1','N2','N3', 'ABREVIATURA', 'UNIDAD', 'ID_TECNICA','N7','N8','N9','NOMBRE_TOXICO','TECNICA_MEDIDA' ]
toxicos = toxicos[['ID_TOXICO','NOMBRE_TOXICO','ABREVIATURA', 'UNIDAD', 'ID_TECNICA','TECNICA_MEDIDA']]

# %%
aire2018['TOTAL'] = aire2018.D01 + aire2018.D02 + aire2018.D03 + aire2018.D04 + aire2018.D05 + aire2018.D06 + aire2018.D07 + aire2018.D08 + aire2018.D09 + aire2018.D10+ aire2018.D11 + aire2018.D12 + aire2018.D13 + aire2018.D14 + aire2018.D15 + aire2018.D16 + aire2018.D17 + aire2018.D18 + aire2018.D19 + aire2018.D20 + aire2018.D21 + aire2018.D22 + aire2018.D23 + aire2018.D24 + aire2018.D25 + aire2018.D26 + aire2018.D27 + aire2018.D28 + aire2018.D29 + aire2018.D30 + aire2018.D31

# %% [markdown]
# ### Mergeamos Aire DF y Toxicos DF

# %%
aire = pd.merge(aire2018, toxicos, how='outer', on=None,
               left_on='MAGNITUD',right_on = 'ID_TOXICO', indicator = True)

# %%
aire[aire['_merge']=='right_only']
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO  ANO  MES  D01  \
# 1806        NaN        NaN       NaN       NaN            NaN  NaN  NaN  NaN
# 1807        NaN        NaN       NaN       NaN            NaN  NaN  NaN  NaN
# 1808        NaN        NaN       NaN       NaN            NaN  NaN  NaN  NaN
#
#       V01  D02     ...     D31  V31 TOTAL  ID_TOXICO NOMBRE_TOXICO  \
# 1806  NaN  NaN     ...     NaN  NaN   NaN         37  Metaxileno
# 1807  NaN  NaN     ...     NaN  NaN   NaN         38  Paraxileno
# 1808  NaN  NaN     ...     NaN  NaN   NaN         39  Ortoxileno
#
#       ABREVIATURA UNIDAD  ID_TECNICA TECNICA_MEDIDA      _merge
# 1806          MXY  µg/m3          59          Id.    right_only
# 1807          PXY  µg/m3          59          Id.    right_only
# 1808          OXY  µg/m3          59          Id.    right_only
#
# [3 rows x 77 columns]

# %%
print(len(aire))
aire = aire.dropna()
print(len(aire))
# Out:
# 1809
# 1806

# %%
aire.describe()
# Out:
#        PROVINCIA  MUNICIPIO     ESTACION     MAGNITUD     ANO          MES  \
# count     1806.0     1806.0  1806.000000  1806.000000  1806.0  1806.000000
# mean        28.0       79.0    34.651163    13.159468  2018.0     6.500000
# std          0.0        0.0    17.959731    10.524897     0.0     3.457338
# min         28.0       79.0     4.000000     1.000000  2018.0     1.000000
# 25%         28.0       79.0    18.000000     7.000000  2018.0     3.000000
# 50%         28.0       79.0    38.000000    10.000000  2018.0     6.500000
# 75%         28.0       79.0    54.000000    14.000000  2018.0    10.000000
# max         28.0       79.0    60.000000    44.000000  2018.0    12.000000
#
#                D01          D02          D03          D04     ...       \
# count  1806.000000  1806.000000  1806.000000  1806.000000     ...
# mean     24.953156    23.037774    25.342359    25.894452     ...
# std      32.467819    26.509996    29.414667    41.258465     ...
# min       0.000000     0.000000     0.000000     0.000000     ...
# 25%       1.572500     1.800000     2.000000     1.662500     ...
# 50%      12.500000    12.000000    14.500000    11.000000     ...
# 75%      37.000000    37.000000    40.000000    35.000000     ...
# max     236.000000   174.000000   207.000000   461.000000     ...
#
#                D25          D26          D27          D28          D29  \
# count  1806.000000  1806.000000  1806.000000  1806.000000  1806.000000
# mean     28.914751    29.721711    29.740255    28.475044    24.145559
# std      37.169653    40.050881    39.623131    40.089131    37.240642
# min      -0.050000     0.000000     0.000000    -0.060000     0.000000
# 25%       2.000000     2.000000     2.000000     2.000000     1.000000
# 50%      16.000000    16.000000    16.000000    14.000000     9.500000
# 75%      45.000000    44.000000    45.000000    41.000000    35.000000
# max     298.000000   378.000000   350.000000   352.000000   610.000000
#
#                D30          D31        TOTAL    ID_TOXICO   ID_TECNICA
# count  1806.000000  1806.000000  1806.000000  1806.000000  1806.000000
# mean     23.791190    18.942481   793.365327    13.159468    22.740864
# std      33.781192    40.426750   906.658101    10.524897    20.965011
# min       0.000000     0.000000     1.220000     1.000000     2.000000
# 25%       1.000000     0.000000    73.000000     7.000000     8.000000
# 50%      10.000000     0.500000   504.000000    10.000000     8.000000
# 75%      35.000000    19.000000  1201.000000    14.000000    47.000000
# max     297.000000   358.000000  6315.000000    44.000000    59.000000
#
# [8 rows x 40 columns]

# %%
# PENDIENTE. 
# LLEGAR A LA COLUMNA "TOTAL" DE UN MODO MAS OPTIMIZADO

# %%
aire.groupby(['ESTACION','NOMBRE_TOXICO']).TOTAL.sum()
# Out:
# ESTACION  NOMBRE_TOXICO
# 4.0       Dióxido de Azufre                       2980.00
#           Dióxido de Nitrógeno                   15672.00
#           Monóxido de Carbono                      148.40
#           Monóxido de Nitrógeno                   9944.00
#           Óxidos de Nitrógeno                    30917.00
# 8.0       Benceno                                  256.90
#           Dióxido de Azufre                       1785.00
#           Dióxido de Nitrógeno                   20003.00
#           Etilbenceno                              145.50
#           Hidrocarburos no metánicos (hexano)       26.22
#           Hidrocarburos totales (hexano)           564.20
#           Metano                                   538.50
#           Monóxido de Carbono                      137.00
#           Monóxido de Nitrógeno                   9510.00
#           Ozono                                  17276.00
#           Partículas < 10 µm                      7516.00
#           Partículas < 2.5 µm                     4089.00
#           Tolueno                                  981.60
#           Óxidos de Nitrógeno                    34582.00
# 11.0      Benceno                                  148.90
#           Dióxido de Nitrógeno                   15616.00
#           Etilbenceno                              120.50
#           Monóxido de Nitrógeno                   6994.00
#           Tolueno                                  882.20
#           Óxidos de Nitrógeno                    26343.00
# 16.0      Dióxido de Nitrógeno                   13359.00
#           Monóxido de Carbono                      109.80
#           Monóxido de Nitrógeno                   5394.00
#           Ozono                                  18011.00
#           Óxidos de Nitrógeno                    21632.00
#                                                    ...
# 55.0      Hidrocarburos totales (hexano)           503.34
#           Metano                                   469.14
#           Monóxido de Nitrógeno                   7378.00
#           Partículas < 10 µm                      7622.00
#           Tolueno                                  630.60
#           Óxidos de Nitrógeno                    26336.00
# 56.0      Dióxido de Nitrógeno                   19177.00
#           Monóxido de Carbono                      136.90
#           Monóxido de Nitrógeno                  13346.00
#           Ozono                                  15707.00
#           Óxidos de Nitrógeno                    39645.00
# 57.0      Dióxido de Azufre                       3069.00
#           Dióxido de Nitrógeno                   11476.00
#           Monóxido de Carbono                      107.80
#           Monóxido de Nitrógeno                   4783.00
#           Partículas < 10 µm                      6137.00
#           Óxidos de Nitrógeno                    18810.00
# 58.0      Dióxido de Nitrógeno                    5459.00
#           Monóxido de Nitrógeno                   1776.00
#           Ozono                                  20852.00
#           Óxidos de Nitrógeno                     8216.00
# 59.0      Dióxido de Nitrógeno                    9280.00
#           Monóxido de Nitrógeno                   4082.00
#           Ozono                                  20220.00
#           Óxidos de Nitrógeno                    15543.00
# 60.0      Dióxido de Nitrógeno                   10322.00
#           Monóxido de Nitrógeno                   4220.00
#           Ozono                                  22096.00
#           Partículas < 10 µm                      6404.00
#           Óxidos de Nitrógeno                    16789.00
# Name: TOTAL, Length: 151, dtype: float64

# %%
plt.hist(aire.TOTAL,500)
plt.show()
